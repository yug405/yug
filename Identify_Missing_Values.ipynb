# %% [markdown]
# <a href="https://colab.research.google.com/github/yug405/yug/blob/main/Identify_Missing_Values.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import library
import pandas as pd

# %%
# read data
titanic = pd.read_csv('https://github.com/YBIFoundation/Dataset/raw/main/Titanic.csv')

# %%
# info [provides count of non-missin values]
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
# count missing values
titanic.isna().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           263
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
# count missing values
titanic.isnull().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           263
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
# count non-missing values
titanic.notna().sum()
# Out:
# pclass       1309
# survived     1309
# name         1309
# sex          1309
# age          1046
# sibsp        1309
# parch        1309
# ticket       1309
# fare         1308
# cabin         295
# embarked     1307
# boat          486
# body          121
# home.dest     745
# dtype: int64

# %%
# count non-missing values
titanic.notnull().sum()
# Out:
# pclass       1309
# survived     1309
# name         1309
# sex          1309
# age          1046
# sibsp        1309
# parch        1309
# ticket       1309
# fare         1308
# cabin         295
# embarked     1307
# boat          486
# body          121
# home.dest     745
# dtype: int64

# %%
titanic.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881138     0.498854     0.385027
# std       0.837836     0.486055    14.413493     1.041658     0.865560
# min       1.000000     0.000000     0.170000     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
titanic.shape
# Out:
# (1309, 14)

# %%
titanic.tail()
# Out:
#       pclass  survived                       name     sex   age  sibsp  parch  \
# 1304       3         0       Zabour, Miss. Hileni  female  14.5      1      0
# 1305       3         0      Zabour, Miss. Thamine  female   NaN      1      0
# 1306       3         0  Zakarian, Mr. Mapriededer    male  26.5      0      0
# 1307       3         0        Zakarian, Mr. Ortin    male  27.0      0      0
# 1308       3         0         Zimmerman, Mr. Leo    male  29.0      0      0
#
#       ticket     fare cabin embarked boat   body home.dest
# 1304    2665  14.4542   NaN        C  NaN  328.0       NaN
# 1305    2665  14.4542   NaN        C  NaN    NaN       NaN
# 1306    2656   7.2250   NaN        C  NaN  304.0       NaN
# 1307    2670   7.2250   NaN        C  NaN    NaN       NaN
# 1308  315082   7.8750   NaN        S  NaN    NaN       NaN

# %%
titanic.age.hist()
# Out:
# <Axes: >

# %%
import seaborn as sns
sns.boxplot(titanic.age)
# Out:
# <Axes: ylabel='age'>

# %%
titanic=titanic[titanic.age<60]

# %%
titanic.shape
# Out:
# (1006, 14)

# %%
titanic.sex.hist()
# Out:
# <Axes: >

# %%
titanic.fillna(titanic.median())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-da48e4a1d6df> in <cell line: 0>()
# ----> 1 titanic.fillna(titanic.median())
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in median(self, axis, skipna, numeric_only, **kwargs)
#   11704         **kwargs,
#   11705     ):
# > 11706         result = super().median(axis, skipna, numeric_only, **kwargs)
#   11707         if isinstance(result, Series):
#   11708             result = result.__finalize__(self, method="median")
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in median(self, axis, skipna, numeric_only, **kwargs)
#   12429         **kwargs,
#   12430     ) -> Series | float:
# > 12431         return self._stat_function(
#   12432             "median", nanops.nanmedian, axis, skipna, numeric_only, **kwargs
#   12433         )
#
# ...

# %%
titanic.fillna(numeric cols median, inplace=True)
# Out:
#   File "<ipython-input-18-ac27eddea45f>", line 1
#     titanic.fillna(numeric cols median, inplace=True)
#                    ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
