# %%
import pandas as pd

# %%
df = pd.read_csv("/content/covid19_country_wise_tracker.csv")

# %%
df
# Out:
#            Date    Country  Confirmed  Recovered   Deaths   Active  New_Cases  \
# 0    2025-04-03        USA   45376478   42423578  1142406  1810494      90032
# 1    2025-04-04        USA   45467166   42492978  1144508  1829680      90688
# 2    2025-04-05        USA   45558237   42558478  1146326  1853433      91071
# 3    2025-04-06        USA   45649683   42636944  1147262  1865477      91446
# 4    2025-04-07        USA   45740110   42703757  1149219  1887134      90427
# ..          ...        ...        ...        ...      ...      ...        ...
# 595  2025-05-28  Australia   47380233   40074825   924748  6380660      93613
# 596  2025-05-29  Australia   47472984   40148990   926520  6397474      92751
# 597  2025-05-30  Australia   47567714   40224256   927532  6415926      94730
# 598  2025-05-31  Australia   47663473   40308408   928849  6426216      95759
# 599  2025-06-01  Australia   47757885   40387505   931057  6439323      94412
#
# ...

# %%
df.describe()
# Out:
#           Confirmed     Recovered        Deaths        Active      New_Cases  \
# count  6.000000e+02  6.000000e+02  6.000000e+02  6.000000e+02     600.000000
# mean   4.047238e+07  3.636982e+07  8.821783e+05  3.220380e+06   80822.485000
# std    1.484069e+07  1.348356e+07  3.884367e+05  1.866435e+06   29667.548299
# min    6.824978e+06  6.238809e+06  1.174030e+05  4.687660e+05   12000.000000
# 25%    3.639093e+07  3.264419e+07  4.994150e+05  1.878324e+06   72529.250000
# 50%    4.669230e+07  4.276818e+07  9.802945e+05  2.765926e+06   93267.500000
# 75%    5.038763e+07  4.553113e+07  1.206616e+06  5.346218e+06  100675.250000
# max    5.578939e+07  5.058500e+07  1.383692e+06  6.652535e+06  112679.000000
#
#         New_Deaths  Vaccination_Rate
# count   600.000000        600.000000
# mean   1609.440000         74.894717
# std     788.437117          6.164985
# min     146.000000         64.490000
# 25%    1013.750000         69.720000
# 50%    1630.000000         73.810000
# ...

# %%
df.tail()
# Out:
#            Date    Country  Confirmed  Recovered  Deaths   Active  New_Cases  \
# 595  2025-05-28  Australia   47380233   40074825  924748  6380660      93613
# 596  2025-05-29  Australia   47472984   40148990  926520  6397474      92751
# 597  2025-05-30  Australia   47567714   40224256  927532  6415926      94730
# 598  2025-05-31  Australia   47663473   40308408  928849  6426216      95759
# 599  2025-06-01  Australia   47757885   40387505  931057  6439323      94412
#
#      New_Deaths  Vaccination_Rate
# 595        2318             78.85
# 596        1772             78.92
# 597        1012             78.95
# 598        1317             79.03
# 599        2208             79.10

# %%
df.head(10)
# Out:
#          Date Country  Confirmed  Recovered   Deaths   Active  New_Cases  \
# 0  2025-04-03     USA   45376478   42423578  1142406  1810494      90032
# 1  2025-04-04     USA   45467166   42492978  1144508  1829680      90688
# 2  2025-04-05     USA   45558237   42558478  1146326  1853433      91071
# 3  2025-04-06     USA   45649683   42636944  1147262  1865477      91446
# 4  2025-04-07     USA   45740110   42703757  1149219  1887134      90427
# 5  2025-04-08     USA   45831781   42780646  1150634  1900501      91671
# 6  2025-04-09     USA   45924781   42854582  1151848  1918351      93000
# 7  2025-04-10     USA   46016498   42929141  1153970  1933387      91717
# 8  2025-04-11     USA   46106955   43006191  1155968  1944796      90457
# 9  2025-04-12     USA   46198545   43085655  1157905  1954985      91590
#
#    New_Deaths  Vaccination_Rate
# 0        2492             64.49
# 1        2102             64.57
# 2        1818             64.58
# 3         936             64.68
# ...

# %%
df.shape
# Out:
# (600, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              600 non-null    object
#  1   Country           600 non-null    object
#  2   Confirmed         600 non-null    int64
#  3   Recovered         600 non-null    int64
#  4   Deaths            600 non-null    int64
#  5   Active            600 non-null    int64
#  6   New_Cases         600 non-null    int64
#  7   New_Deaths        600 non-null    int64
#  8   Vaccination_Rate  600 non-null    float64
# dtypes: float64(1), int64(6), object(2)
# memory usage: 42.3+ KB

# %%
df.Vaccination_Rate
# Out:
# 0      64.49
# 1      64.57
# 2      64.58
# 3      64.68
# 4      64.69
#        ...
# 595    78.85
# 596    78.92
# 597    78.95
# 598    79.03
# 599    79.10
# Name: Vaccination_Rate, Length: 600, dtype: float64

# %%
df.Vaccination_Rate.hist()
# Out:
# <Axes: >

# %%
import seaborn as sns
sns.boxplot(df.Vaccination_Rate)
# Out:
# <Axes: ylabel='Vaccination_Rate'>

# %%
df = df[df.Vaccination_Rate>=20]

# %%
df.shape
# Out:
# (600, 9)

# %%
sns.boxplot(df.Vaccination_Rate)
# Out:
# <Axes: >

# %%
df.Deaths.hist()
# Out:
# <Axes: >

# %%
df.isna().sum()
# Out:
# Date                0
# Country             0
# Confirmed           0
# Recovered           0
# Deaths              0
# Active              0
# New_Cases           0
# New_Deaths          0
# Vaccination_Rate    0
# dtype: int64

# %%
df.isin([0]).sum()
# Out:
# Date                0
# Country             0
# Confirmed           0
# Recovered           0
# Deaths              0
# Active              0
# New_Cases           0
# New_Deaths          0
# Vaccination_Rate    0
# dtype: int64
